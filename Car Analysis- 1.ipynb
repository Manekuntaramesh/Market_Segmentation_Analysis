# %%
import numpy as np
import pandas as pd

# %%
data1 = pd.read_csv(r"C:\rock\Data Science\Fenny\Car details v3.csv")

# %%
data1
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
# Data Preparation

# %%
# missing values

# %%
data1.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %%
# Extract numerical values from strings.

# %%
data1['mileage'] = data1['mileage'].str.extract('(\d+\.\d+|\d+)').astype(float)

# %%
data1['engine'] = data1['engine'].str.extract('(\d+\.\d+|\d+)').astype(float)

# %%
data1['max_power'] = data1['max_power'].str.extract('(\d+\.\d+|\d+)').astype(float)

# %%
# filling the missing value -- fillna method

# %%
data1['mileage'].fillna(data1['mileage'].median(),inplace = True)
data1['engine'].fillna(data1['engine'].median(),inplace = True)
data1['max_power'].fillna(data1['max_power'].median(),inplace = True)

# %%
data1.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage            0
# engine             0
# max_power          0
# torque           222
# seats            221
# dtype: int64

# %%
data1['torque'] = data1['torque'].str.extract('(\d+\.\d+|\d+)').astype(float)

# %%
data1['torque'].fillna(data1['torque'].median(),inplace = True)

# %%
data1['seats'].fillna(data1['seats'].mode()[0],inplace = True)

# %%
data1.isna().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# torque           0
# seats            0
# dtype: int64

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        8128 non-null   float64
#  9   engine         8128 non-null   float64
#  10  max_power      8128 non-null   float64
#  11  torque         8128 non-null   float64
#  12  seats          8128 non-null   float64
# dtypes: float64(5), int64(3), object(5)
# memory usage: 825.6+ KB

# %%
data1.head(4)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
#
#   seller_type transmission         owner  mileage  engine  max_power  torque  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00   190.0
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52   250.0
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00    12.7
# 3  Individual       Manual   First Owner    23.00  1396.0      90.00    22.4
#
#    seats
# 0    5.0
# 1    5.0
# 2    5.0
# 3    5.0

# %%
# checking duplicates

# %%
data1.duplicated().sum()
# Out:
# 1202

# %%
data1.drop_duplicates(inplace = True)

# %%
data1.duplicated().sum()
# Out:
# 0

# %%
#clean 'owner' column for simplified analysis

# %%
data1['ower_clean'] = data1['owner'].apply(lambda x:x.split()[0])

# %%
# Extract brand from car name

# %%
data1['brand'] = data1['name'].apply(lambda x: x.split()[0])

# %%
from datetime import datetime

# %%
current_year = datetime.now().year
data1['car_age'] = current_year - data1['year']

# %%
data1.head(3)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
#
#   seller_type transmission         owner  mileage  engine  max_power  torque  \
# 0  Individual       Manual   First Owner    23.40  1248.0      74.00   190.0
# 1  Individual       Manual  Second Owner    21.14  1498.0     103.52   250.0
# 2  Individual       Manual   Third Owner    17.70  1497.0      78.00    12.7
#
#    seats ower_clean   brand  car_age
# 0    5.0      First  Maruti       11
# 1    5.0     Second   Skoda       11
# 2    5.0      Third   Honda       19

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6926 entries, 0 to 8125
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6926 non-null   object
#  1   year           6926 non-null   int64
#  2   selling_price  6926 non-null   int64
#  3   km_driven      6926 non-null   int64
#  4   fuel           6926 non-null   object
#  5   seller_type    6926 non-null   object
#  6   transmission   6926 non-null   object
#  7   owner          6926 non-null   object
#  8   mileage        6926 non-null   float64
#  9   engine         6926 non-null   float64
#  10  max_power      6926 non-null   float64
#  11  torque         6926 non-null   float64
#  12  seats          6926 non-null   float64
#  13  ower_clean     6926 non-null   object
#  14  brand          6926 non-null   object
#  15  car_age        6926 non-null   int64
# dtypes: float64(5), int64(4), object(7)
# memory usage: 919.9+ KB

# %%
# Visualization Car details

# %%
# Selling price vs car  age

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(data=data1, x='car_age', y='selling_price', hue='fuel')
plt.title('Selling Price vs Car Age by Fuel Type')
plt.xlabel('Car Age (years)')
plt.ylabel('Selling Price (INR)')
plt.show()

# %%
# Distribution of owners

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=data1, x='ower_clean', order=data1['ower_clean'].value_counts().index)
plt.title('Ownership Status Distribution')
plt.xlabel('Owner Type')
plt.ylabel('Count')
plt.show()

# %%
# Ownership Impact on Price

# %%
sns.boxplot(data=data1, x='ower_clean', y='selling_price')
plt.title("Price Distribution by Ownership Type")
plt.xlabel("Ownership")
plt.ylabel("Selling Price (INR)")
plt.show()

# %%
# Top Brands & Models

# %%
top_brands = data1['brand'].value_counts().head(10)
sns.barplot(x=top_brands.index, y=top_brands.values)
plt.title("Top 10 Most Common Car Brands")
plt.ylabel("Number of Listings")
plt.xlabel("Brand")
plt.xticks(rotation=45)
plt.show()

# %%
#Mileage vs Price Trade-off

# %%
sns.scatterplot(data=data1, x='mileage', y='selling_price')
plt.title("Mileage vs Selling Price")
plt.xlabel("Mileage (kmpl)")
plt.ylabel("Selling Price (INR)")
plt.show()

# %%
#Fuel Type Distribution

# %%
fuel_counts = data1['fuel'].value_counts()
sns.barplot(x=fuel_counts.index, y=fuel_counts.values)
plt.title("Fuel Type Distribution")
plt.ylabel("Count")
plt.xlabel("Fuel Type")
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(10,6))
sns.heatmap(data1[['selling_price', 'km_driven', 'mileage', 'engine', 'max_power', 'car_age']].corr(), annot=True, cmap='coolwarm')
plt.title('Feature Correlation Matrix')
plt.show()
